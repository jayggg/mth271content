# %% [markdown]
# ___
#
#
# # Exercise: Iris flower dataset
# ___
#
# The statistical visualization package [`seaborn`](https://seaborn.pydata.org) comes with the famous [Iris Flower Dataset](https://en.wikipedia.org/wiki/Iris_flower_data_set). Your exercise is to give one-line codes to address the two tasks mentioned after the figure below.

# %%
import pandas as pd
# %matplotlib inline
import seaborn; seaborn.set()

iris = seaborn.load_dataset('iris')
seaborn.pairplot(iris, hue='species');

# %% [markdown]
# #### Task 1: Make a bar plot of the mean sepal sizes for each species

# %% [markdown]
# #### Task 2: Find the min, max and mean of petal sizes for each species
